# %%
import cv2
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import glob

# %%
lab=[cv2.imread(files,0) for files in glob.glob(r"C:/Users/admin/Downloads/chromedriver_win32/downloads/labrador retriever/*.jpg")]
german=[cv2.imread(files,0) for files in glob.glob(r"C:/Users/admin/Downloads/chromedriver_win32/downloads/German Shepherd/*.jpg")]
bulld=[cv2.imread(files,0) for files in glob.glob(r"C:/Users/admin/Downloads/chromedriver_win32/downloads/bulldog/*.jpg")]
pit=[cv2.imread(files,0) for files in glob.glob(r"C:/Users/admin/Downloads/chromedriver_win32/downloads/Pitbull dogs/*.jpg")]
pug=[cv2.imread(files,0) for files in glob.glob(r"C:/Users/admin/Downloads/chromedriver_win32/downloads/Pug/*.jpg")]

# %%
persian=[cv2.imread(files,0) for files in glob.glob(r"C:/Users/admin/Downloads/chromedriver_win32/downloads/Persian cats/*.jpg")]
rag=[cv2.imread(files,0) for files in glob.glob(r"C:/Users/admin/Downloads/chromedriver_win32/downloads/ragdoll cat/*.jpg")]
sph=[cv2.imread(files,0) for files in glob.glob(r"C:/Users/admin/Downloads/chromedriver_win32/downloads/sphynx cat/*.jpg")]
shorthair=[cv2.imread(files,0) for files in glob.glob(r"C:/Users/admin/Downloads/chromedriver_win32/downloads/american shorthair cat/*.jpg")]
burm=[cv2.imread(files,0) for files in glob.glob(r"C:/Users/admin/Downloads/chromedriver_win32/downloads/burmilla cat/*.jpg")]

# %%
import matplotlib.pyplot as plt

# %%
for i in range(len(burm)):
    burm[i]=cv2.resize(burm[i],(300,300))
for i in range(len(rag)):
    rag[i]=cv2.resize(rag[i],(300,300))
for i in range(len(sph)):
    sph[i]=cv2.resize(sph[i],(300,300))
for i in range(len(shorthair)):
    shorthair[i]=cv2.resize(shorthair[i],(300,300))
for i in range(len(persian)):
    persian[i]=cv2.resize(persian[i],(300,300))
for i in range(len(lab)):
    lab[i]=cv2.resize(lab[i],(300,300))
for i in range(len(german)):
    german[i]=cv2.resize(german[i],(300,300))
for i in range(len(pit)):
    pit[i]=cv2.resize(pit[i],(300,300))
for i in range (len(bulld)):
    bulld[i]=cv2.resize(bulld[i],(300,300))
for i in range(len(pug)):
    pug[i]=cv2.resize(pug[i],(300,300))

# %%
plt.matshow(pit[98])

# %%
#creating a 1D list of all the classes
CatnDog=[]
i=0
while True:
    lablist=[]
    for j in lab[i]:
        for k in j:
            lablist.append(k)
    i+=1
    CatnDog.append(lablist)
    if i==len(lab):
        break
i=0
while True:
    germlist=[]
    for j in german[i]:
        for k in j:
            germlist.append(k)
    i+=1
    CatnDog.append(germlist)
    if i==len(german):
        break
i=0
while True:
    bullist=[]
    for j in bulld[i]:
        for k in j:
            bullist.append(k)
    i+=1
    CatnDog.append(bullist)
    if i==len(bulld):
        break
i=0
while True:
    pitlist=[]
    for j in pit[i]:
        for k in j:
            pitlist.append(k)
    i+=1
    CatnDog.append(pitlist)
    if i==len(pit):
        break
i=0
while True:
    puglist=[]
    for j in pug[i]:
        for k in j:
            puglist.append(k)
    i+=1
    CatnDog.append(puglist)
    if i==len(pug):
        break
i=0
while True:
    persianlist=[]
    for j in persian[i]:
        for k in j:
            persianlist.append(k)
    i+=1
    CatnDog.append(persianlist)
    if i==len(persian):
        break
i=0
while True:
    raglist=[]
    for j in rag[i]:
        for k in j:
            raglist.append(k)
    i+=1
    CatnDog.append(raglist)
    if i==len(rag):
        break
i=0
while True:
    sphlist=[]
    for j in sph[i]:
        for k in j:
            sphlist.append(k)
    i+=1
    CatnDog.append(sphlist)
    if i==len(sph):
        break
i=0
while True:
    shorthairlist=[]
    for j in shorthair[i]:
        for k in j:
            shorthairlist.append(k)
    i+=1
    CatnDog.append(shorthairlist)
    if i==len(shorthair):
        break
i=0
while True:
    burmlist=[]
    for j in burm[i]:
        for k in j:
            burmlist.append(k)
    i+=1
    CatnDog.append(burmlist)
    if i==len(burm):
        break

# %%
output_list=[]

# %%
for i in range(len(lab)):
    output_list.append("Animal= Dog Breed= Labrador")
for i in range(len(lab),len(lab)+len(german)):
    output_list.append("Animal= Dog Breed= German Shepherd")
for i in range(len(lab)+len(german),len(lab)+len(german)+len(bulld)):
    output_list.append("Animal= Dog Breed= Bull Dog")
for i in range(len(lab)+len(german)+len(bulld),len(lab)+len(german)+len(bulld)+len(pit)):
    output_list.append("Animal= Dog Breed= Pitbull")
for i in range(len(lab)+len(german)+len(bulld)+len(pit),len(lab)+len(german)+len(bulld)+len(pit)+len(pug)):
    output_list.append("Animal= Dog Breed= Pug")
for i in range(len(lab)+len(german)+len(bulld)+len(pit)+len(pug),len(lab)+len(german)+len(bulld)+len(pit)+len(pug)+len(persian)):
    output_list.append("Animal= Cat Breed= Persian")
for i in range(len(lab)+len(german)+len(bulld)+len(pit)+len(pug)+len(persian),len(lab)+len(german)+len(bulld)+len(pit)+len(pug)+len(persian)+len(rag)):
    output_list.append("Animal= Cat Breed= Ragdoll")
for i in range(len(lab)+len(german)+len(bulld)+len(pit)+len(pug)+len(persian)+len(rag),len(lab)+len(german)+len(bulld)+len(pit)+len(pug)+len(persian)+len(rag)+len(sph)):
    output_list.append("Animal= Cat Breed= Sphynx")
for i in range(len(lab)+len(german)+len(bulld)+len(pit)+len(pug)+len(persian)+len(rag)+len(sph),len(lab)+len(german)+len(bulld)+len(pit)+len(pug)+len(persian)+len(rag)+len(sph)+len(shorthair)):
    output_list.append("Animal= Cat Breed= American Shorthair")
for i in range(len(lab)+len(german)+len(bulld)+len(pit)+len(pug)+len(persian)+len(rag)+len(sph)+len(shorthair),len(lab)+len(german)+len(bulld)+len(pit)+len(pug)+len(persian)+len(rag)+len(sph)+len(shorthair)+len(burm)):
    output_list.append("Animal= Cat Breed= Burmilla")

# %%
CatnDog=np.array(CatnDog)

# %%
knn=KNeighborsClassifier(n_neighbors=11)

# %%
svc=SVC(gamma=0.001)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(CatnDog,output_list,test_size=.35,random_state=1)

# %%
Klearner=knn.fit(x_train,y_train)

# %%
Slearner=svc.fit(x_train,y_train)

# %%
KP=Klearner.predict(x_test)

# %%
SP=Slearner.predict(x_test)

# %%
accuracy_score(y_test,KP)
# Out:
# 0.22157434402332363

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
cf=RandomForestClassifier(n_estimators=20, random_state=1)

# %%
cf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=20, n_jobs=1,
#             oob_score=False, random_state=1, verbose=0, warm_start=False)

# %%
pp=cf.predict(x_test)

# %%
accuracy_score(y_test,pp)
# Out:
# 0.23323615160349853

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier(random_state=0)

# %%
d=dt.fit(x_train,y_train)

# %%
ppp=d.predict(x_test)

# %%
accuracy_score(y_test,ppp)
# Out:
# 0.16909620991253643
